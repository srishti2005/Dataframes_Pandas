# %% [markdown]
# DataFrames- workspaces of pandas and are directly

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Seed gives the boundary value for fetching the random numbers

# %%
from numpy.random import randn
np.random.seed(101)

# %% [markdown]
# Creating a table  of mentioned number of rows and columns and giving the rows and columns index name as ABCDE AND WXYZ respectively

# %%
df = pd.DataFrame(randn(5,4),index='A B C D E'.split(),columns='W X Y Z'.split())

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# Selection and indexing

# %% [markdown]
# Printing only column W

# %%
df['W']
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %% [markdown]
# Printing list of columns

# %%
df[['W','Y']]
# Out:
#           W         Y
# A  2.706850  0.907969
# B  0.651118 -0.848077
# C -2.018168  0.528813
# D  0.188695 -0.933237
# E  0.190794  2.605967

# %% [markdown]
# SQL Syntax (not recomended)

# %% [markdown]
# Knowing the type od data in DataFrame

# %%
type(df['Y'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Creating a new column

# %%
df['new'] = df['W'] + df['Y']

# %%
df
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %%
df['new1'] = df['W'] + df['Y'] +df['Z']

# %%
df
# Out:
#           W         X         Y         Z       new      new1
# A  2.706850  0.628133  0.907969  0.503826  3.614819  4.118645
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959  0.409006
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355 -2.078355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542  0.210515
# E  0.190794  1.978757  2.605967  0.683509  2.796762  3.480270

# %% [markdown]
# Removing Columns

# %%
df.drop('new',axis=1)
# Out:
#           W         X         Y         Z      new1
# A  2.706850  0.628133  0.907969  0.503826  4.118645
# B  0.651118 -0.319318 -0.848077  0.605965  0.409006
# C -2.018168  0.740122  0.528813 -0.589001 -2.078355
# D  0.188695 -0.758872 -0.933237  0.955057  0.210515
# E  0.190794  1.978757  2.605967  0.683509  3.480270

# %% [markdown]
# Droping a column in the dataFrame itself

# %%
df.drop('new',axis=1,inplace=True)

# %%
df
# Out:
#           W         X         Y         Z      new1
# A  2.706850  0.628133  0.907969  0.503826  4.118645
# B  0.651118 -0.319318 -0.848077  0.605965  0.409006
# C -2.018168  0.740122  0.528813 -0.589001 -2.078355
# D  0.188695 -0.758872 -0.933237  0.955057  0.210515
# E  0.190794  1.978757  2.605967  0.683509  3.480270

# %% [markdown]
# Representing the table in transposed form

# %%
df.loc['A']
# Out:
# W       2.706850
# X       0.628133
# Y       0.907969
# Z       0.503826
# new1    4.118645
# Name: A, dtype: float64

# %% [markdown]
# TO print only the data of a single row

# %%
df.iloc[C]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-e15dd090e44c> in <cell line: 1>()
# ----> 1 df.iloc[C]
#
# NameError: name 'C' is not defined

# %% [markdown]
# To print the info on one cell

# %%
df.loc['B','Y']
# Out:
# -0.8480769834036315

# %% [markdown]
# To print the data of desired rows and columns

# %%
df.loc[['A','B'],['W','Y']]
# Out:
#           W         Y
# A  2.706850  0.907969
# B  0.651118 -0.848077

# %%
df>0
# Out:
#        W      X      Y      Z   new1
# A   True   True   True   True   True
# B   True  False  False   True   True
# C  False   True   True  False  False
# D   True  False  False   True   True
# E   True   True   True   True   True

# %%
df[df>0]

# %% [markdown]
# To print the values of the column where the values are > 0

# %%
df[df['W']>0]

# %% [markdown]
# To print the values of column Y for which correspomding values of column W are >0

# %%
df[df['W']>0]['Y']

# %%
df[df['W']>0]['Y','X']

# %%
df[(df['W '>0) & (df['Y'>1])]

# %% [markdown]
# To reset the index

# %%
df.reset_index()

# %% [markdown]
# adding new column as splited values

# %%
newind= 'CA NY WY OR CO'.split()

# %%
df['states']=newind
